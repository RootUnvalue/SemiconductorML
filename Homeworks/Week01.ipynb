# %% [markdown]
# 00) 0.7071067811865476
#
#
#
#
# 01)
#
#     1-1) Learning Problem, Data(관측값)은 있지만 f(system)이 알려지지 않은 경우입니다.
#
#     1-2) Input은 주택들의 면적, 방의 수, 건축연도,  위치이고, Output은 주택의 가격입니다.
#
#     1-3) f는 알려져있지 않아 Data로부터 찾아야합니다.
#
#
#
#
# 02)
#
#     2-1) 과목을 이수하지 못할 가능성이 높은 학생 미리 찾기.
#
#     2-2) 출석, 과제 점수, Quiz 성적, 중간고사 성적
#
#     2-3) 출석, 과제 점수, Quiz 성적, 중간고사 성적
#
#     2-4) 과목의 이수여부
#
#     2-5) Supervised Learning(분류)
#
#     2-6) 과거의 학생들의 출석, 과제 점수, 퀴즈 서적, 중간, 기말고사 성적이 추가로 필요해 보입니다. 지도학습의 과정을 input * f -> output 으로 볼 때, input과 output이 모두 필요하지만, 이 경우에는 input은 있지만 output이 없기에 학습데이터가 불충분하다 생각합니다.
#
#
#
#
# 03)

# %% [markdown]
# ### HW_03
#
# `Input` 디렉토리의 `california_housing.csv`를 Pandas DataFrame으로 읽고 다음 질문에 답하시오.
#
# - DataFrame의 Row 수와 Column 수를 적으시오.
# - `MedHouseVal`의 평균을 적으시오.
# - `MedInc`가 5 이상인 Row의 수를 적으시오.
# - `MedInc`, `HouseAge`, `AveRooms`를 선택하여 DataFrame `X`를 만들고 `X`의 Shape를 적으시오.
#
# 각 문제의 실행 결과를 제출하시오.

# %%
import pandas as pd
import numpy as np

# %%
PATH = "../Input/"
df = pd.read_csv(PATH + "california_housing.csv")

# %%
display(df.head())#head() : 상위 5개 데이터 출력

print("차원 : " , df.shape)#shape : 데이터의 차원 확인

print("MedHouseVal의 평균값 : " , df["MedHouseVal"].mean())#평균값 확인

dfMedInc = df["MedInc"] > 5
print("MedInc가 5보다 큰 데이터 수 : " , df[dfMedInc].shape[0])#조건에 맞는 데이터 수 확인
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422
# 차원 :  (20640, 9)
# MedHouseVal의 평균값 :  2.0685581690891843
# MedInc가 0.5보다 큰 데이터 수 :  4489

# %%
X = df[["MedInc", "HouseAge", "AveRooms"]]
print("X의 차원 : " , X.shape)
# Out:
# X의 차원 :  (20640, 3)
